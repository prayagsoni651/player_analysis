# %%
import pandas as pd  #pd is hust a alias
import numpy as np   #np as a alias

# %% [markdown]
# # Read Excel Sheet

# %%
df = pd.read_csv('Player.csv')    #

# %%
df  # store all the data into df variable
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %% [markdown]
# # Get Top 10 Records

# %%
df.head(10)
# index number is not in my excel sheet its generate automatically
# Out:
#    Player_Id      Player_Name        DOB Batting_Hand          Bowling_Skill  \
# 0          1       SC Ganguly   8-Jul-72    Left_Hand       Right-arm medium
# 1          2      BB McCullum  27-Sep-81   Right_Hand       Right-arm medium
# 2          3       RT Ponting  19-Dec-74   Right_Hand       Right-arm medium
# 3          4        DJ Hussey  15-Jul-77   Right_Hand     Right-arm offbreak
# 4          5  Mohammad Hafeez  17-Oct-80   Right_Hand     Right-arm offbreak
# 5          6         R Dravid  11-Jan-73   Right_Hand     Right-arm offbreak
# 6          7         W Jaffer  16-Feb-78   Right_Hand     Right-arm offbreak
# 7          8          V Kohli   5-Nov-88   Right_Hand       Right-arm medium
# 8          9        JH Kallis  16-Oct-75   Right_Hand  Right-arm fast-medium
# 9         10         CL White  18-Aug-83   Right_Hand        Legbreak googly
#
#         Country  Is_Umpire  Unnamed: 7
# 0         India          0         NaN
# 1   New Zealand          0         NaN
# ...

# %% [markdown]
# # Get last 10 records

# %%
df.tail(10)
# get last 10 record
# Out:
#      Player_Id     Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 513        514       I Shivram        NaN          NaN                 NaN
# 514        515       SD Ranade        NaN          NaN                 NaN
# 515        516  TH Wijewardene        NaN          NaN                 NaN
# 516        517         AL Hill        NaN          NaN                 NaN
# 517        518       RJ Tucker        NaN          NaN                 NaN
# 518        519     Subroto Das        NaN          NaN                 NaN
# 519        520    K Srinivasan        NaN          NaN                 NaN
# 520        521       VK Sharma        NaN          NaN                 NaN
# 521        523     AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524     B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# 513        India          1         NaN
# 514        India          1         NaN
# ...

# %% [markdown]
# # Get the data type of the DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Get all The Columns

# %%
df.columns
# Out:
# Index(['Player_Id', 'Player_Name', 'DOB', 'Batting_Hand', 'Bowling_Skill',
#        'Country', 'Is_Umpire', 'Unnamed: 7'],
#       dtype='object')

# %%
df.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %% [markdown]
# # Store top 10 records into CSV Formet

# %%
df1 = df.head()

# %%
df1.to_csv('top10_records.csv')

# %% [markdown]
# # Read the save data

# %%
pd.read_csv('top10_records.csv')
# Out:
#    Unnamed: 0  Player_Id      Player_Name        DOB Batting_Hand  \
# 0           0          1       SC Ganguly   8-Jul-72    Left_Hand
# 1           1          2      BB McCullum  27-Sep-81   Right_Hand
# 2           2          3       RT Ponting  19-Dec-74   Right_Hand
# 3           3          4        DJ Hussey  15-Jul-77   Right_Hand
# 4           4          5  Mohammad Hafeez  17-Oct-80   Right_Hand
#
#         Bowling_Skill      Country  Is_Umpire  Unnamed: 7
# 0    Right-arm medium        India          0         NaN
# 1    Right-arm medium  New Zealand          0         NaN
# 2    Right-arm medium    Australia          0         NaN
# 3  Right-arm offbreak    Australia          0         NaN
# 4  Right-arm offbreak     Pakistan          0         NaN

# %% [markdown]
# # Convert Column name into csv element

# %%
df = pd.read_csv('Player.csv',header = None)

# %%
df
# Out:
#              0             1          2             3                   4  \
# 0    Player_Id   Player_Name        DOB  Batting_Hand       Bowling_Skill
# 1            1    SC Ganguly   8-Jul-72     Left_Hand    Right-arm medium
# 2            2   BB McCullum  27-Sep-81    Right_Hand    Right-arm medium
# 3            3    RT Ponting  19-Dec-74    Right_Hand    Right-arm medium
# 4            4     DJ Hussey  15-Jul-77    Right_Hand  Right-arm offbreak
# ..         ...           ...        ...           ...                 ...
# 519        519   Subroto Das        NaN           NaN                 NaN
# 520        520  K Srinivasan        NaN           NaN                 NaN
# 521        521     VK Sharma        NaN           NaN                 NaN
# 522        523   AV Wankhade  14-Mar-92    Right_Hand                 NaN
# 523        524   B Aparajith   8-Jul-94    Right_Hand  Right-arm offbreak
#
#                5          6   7
# 0        Country  Is_Umpire NaN
# ...

# %% [markdown]
# # Give my Own Columns name

# %%
df = pd.read_csv('Player.csv' , header = None , names = ['a'  , 'b' , 'c' , 'd', 'e' , 'f' , 'g' , 'h'])

# %%
df
# Out:
#              a             b          c             d                   e  \
# 0    Player_Id   Player_Name        DOB  Batting_Hand       Bowling_Skill
# 1            1    SC Ganguly   8-Jul-72     Left_Hand    Right-arm medium
# 2            2   BB McCullum  27-Sep-81    Right_Hand    Right-arm medium
# 3            3    RT Ponting  19-Dec-74    Right_Hand    Right-arm medium
# 4            4     DJ Hussey  15-Jul-77    Right_Hand  Right-arm offbreak
# ..         ...           ...        ...           ...                 ...
# 519        519   Subroto Das        NaN           NaN                 NaN
# 520        520  K Srinivasan        NaN           NaN                 NaN
# 521        521     VK Sharma        NaN           NaN                 NaN
# 522        523   AV Wankhade  14-Mar-92    Right_Hand                 NaN
# 523        524   B Aparajith   8-Jul-94    Right_Hand  Right-arm offbreak
#
#                f          g   h
# 0        Country  Is_Umpire NaN
# ...

# %% [markdown]
# # Skiped Rows Data

# %%
df = pd.read_csv('Player.csv' , skiprows= [0,4,6,8])

# %%
df
# Out:
#        1       SC Ganguly   8-Jul-72   Left_Hand       Right-arm medium  \
# 0      2      BB McCullum  27-Sep-81  Right_Hand       Right-arm medium
# 1      3       RT Ponting  19-Dec-74  Right_Hand       Right-arm medium
# 2      5  Mohammad Hafeez  17-Oct-80  Right_Hand     Right-arm offbreak
# 3      7         W Jaffer  16-Feb-78  Right_Hand     Right-arm offbreak
# 4      9        JH Kallis  16-Oct-75  Right_Hand  Right-arm fast-medium
# ..   ...              ...        ...         ...                    ...
# 514  519      Subroto Das        NaN         NaN                    NaN
# 515  520     K Srinivasan        NaN         NaN                    NaN
# 516  521        VK Sharma        NaN         NaN                    NaN
# 517  523      AV Wankhade  14-Mar-92  Right_Hand                    NaN
# 518  524      B Aparajith   8-Jul-94  Right_Hand     Right-arm offbreak
#
#             India  0  Unnamed: 7
# 0     New Zealand  0         NaN
# 1       Australia  0         NaN
# ...

# %% [markdown]
# # Where Value == 1 then Convert into NaN Value

# %%
df = pd.read_csv('Player.csv' , na_values= [1])

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          NaN       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1          2.0      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2          3.0       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3          4.0        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4          5.0  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518      519.0      Subroto Das        NaN          NaN                 NaN
# 519      520.0     K Srinivasan        NaN          NaN                 NaN
# 520      521.0        VK Sharma        NaN          NaN                 NaN
# 521      523.0      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522      524.0      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %% [markdown]
# # Where values == 'SC Ganguly' then Convert Into NaN

# %%
df = pd.read_csv('Player.csv' , na_values= 'SC Ganguly')
# you give multiple value seperated by , (comma) and it will converted

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1              NaN   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
df = pd.read_csv('Player.csv')

# %% [markdown]
# # Get Stats of DataFrame

# %%
df.describe()
# Out:
#         Player_Id   Is_Umpire  Unnamed: 7
# count  523.000000  523.000000   12.000000
# mean   262.003824    0.099426    6.500000
# std    151.127981    0.299520    3.605551
# min      1.000000    0.000000    1.000000
# 25%    131.500000    0.000000    3.750000
# 50%    262.000000    0.000000    6.500000
# 75%    392.500000    0.000000    9.250000
# max    524.000000    1.000000   12.000000

# %% [markdown]
# # Get all the columns DataType

# %%
df.dtypes
# Out:
# Player_Id          int64
# Player_Name       object
# DOB               object
# Batting_Hand      object
# Bowling_Skill     object
# Country           object
# Is_Umpire          int64
# Unnamed: 7       float64
# dtype: object

# %%
df = pd.read_csv('Player.csv')

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %% [markdown]
# # Remove Defualt Indexes

# %%
df2 = pd.read_csv('top10_records.csv')

# %%
df2.to_csv('top10_records.csv',index = False)

# %% [markdown]
# # Remove Column Name

# %%
df2.to_csv('top10_records.csv',header=False)

# %% [markdown]
# # all data Seperated By #

# %%
df2.to_csv('top10_records.csv',sep = '#')

# %% [markdown]
# # Store Only Two Columns

# %%
df2.to_csv('result3.csv',columns = ['Player_Id','DOB'])

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %% [markdown]
# # Slicing In DataFrame and Extract The Data

# %%
df.head()
# Out:
#    Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1          2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2          3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3          4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4          5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
#
#        Country  Is_Umpire  Unnamed: 7
# 0        India          0         NaN
# 1  New Zealand          0         NaN
# 2    Australia          0         NaN
# 3    Australia          0         NaN
# 4     Pakistan          0         NaN

# %%
df.columns
# Out:
# Index(['Player_Id', 'Player_Name', 'DOB', 'Batting_Hand', 'Bowling_Skill',
#        'Country', 'Is_Umpire', 'Unnamed: 7'],
#       dtype='object')

# %%
df['Player_Id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 518    519
# 519    520
# 520    521
# 521    523
# 522    524
# Name: Player_Id, Length: 523, dtype: int64

# %% [markdown]
# # Access Multiple Records

# %%
df[['Player_Id','Batting_Hand' , 'DOB']]
# Out:
#      Player_Id Batting_Hand        DOB
# 0            1    Left_Hand   8-Jul-72
# 1            2   Right_Hand  27-Sep-81
# 2            3   Right_Hand  19-Dec-74
# 3            4   Right_Hand  15-Jul-77
# 4            5   Right_Hand  17-Oct-80
# ..         ...          ...        ...
# 518        519          NaN        NaN
# 519        520          NaN        NaN
# 520        521          NaN        NaN
# 521        523   Right_Hand  14-Mar-92
# 522        524   Right_Hand   8-Jul-94
#
# [523 rows x 3 columns]

# %%
df[['Is_Umpire','Player_Id','Batting_Hand']]
# Out:
#      Is_Umpire  Player_Id Batting_Hand
# 0            0          1    Left_Hand
# 1            0          2   Right_Hand
# 2            0          3   Right_Hand
# 3            0          4   Right_Hand
# 4            0          5   Right_Hand
# ..         ...        ...          ...
# 518          1        519          NaN
# 519          1        520          NaN
# 520          1        521          NaN
# 521          0        523   Right_Hand
# 522          0        524   Right_Hand
#
# [523 rows x 3 columns]

# %% [markdown]
# # Convert Series Into DataFrame

# %%
df[['Player_Id']]
# Out:
#      Player_Id
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ..         ...
# 518        519
# 519        520
# 520        521
# 521        523
# 522        524
#
# [523 rows x 1 columns]

# %% [markdown]
# # Series is nothing but one Single Record

# %%
type(df['Player_Id'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Read Excel Sheet

# %%
# pd.read_excel('execfile_name',sheet_name='adding_sheeet_name_as_samefile_name')

# %% [markdown]
# # Read Html Page

# %%
df4 = pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html')

# %%
df4
# Out:
# [       Season   Age   Tm                                       Lg  \
#  0     2008-09  19.0  NaN    Did Not Play (other pro league—Spain)
#  1     2009-10  20.0  OKC                                      NBA
#  2     2010-11  21.0  OKC                                      NBA
#  3     2011-12  22.0  OKC                                      NBA
#  4     2012-13  23.0  OKC                                      NBA
#  5     2013-14  24.0  OKC                                      NBA
#  6     2014-15  25.0  OKC                                      NBA
#  7     2015-16  26.0  OKC                                      NBA
#  8     2016-17  27.0  TOT                                      NBA
#  9     2016-17  27.0  ORL                                      NBA
#  10    2016-17  27.0  TOR                                      NBA
#  11    2017-18  28.0  TOR                                      NBA
#  12    2018-19  29.0  TOR                                      NBA
# ...

# %% [markdown]
# # type Of this data

# %%
type(df4)
# Out:
# list

# %% [markdown]
# # Get How Many Tables We Have

# %%
len(df4)
# Out:
# 7

# %% [markdown]
# # Get the Table Data

# %%
df4[0]
# Out:
#        Season   Age   Tm                                       Lg  \
# 0     2008-09  19.0  NaN    Did Not Play (other pro league—Spain)
# 1     2009-10  20.0  OKC                                      NBA
# 2     2010-11  21.0  OKC                                      NBA
# 3     2011-12  22.0  OKC                                      NBA
# 4     2012-13  23.0  OKC                                      NBA
# 5     2013-14  24.0  OKC                                      NBA
# 6     2014-15  25.0  OKC                                      NBA
# 7     2015-16  26.0  OKC                                      NBA
# 8     2016-17  27.0  TOT                                      NBA
# 9     2016-17  27.0  ORL                                      NBA
# 10    2016-17  27.0  TOR                                      NBA
# 11    2017-18  28.0  TOR                                      NBA
# 12    2018-19  29.0  TOR                                      NBA
# ...

# %%
df4[1]
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS    MP   FG   FGA  ...    FT%  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0    0.0  25.5  3.3   5.8  ...  0.700
# 1     2010-11  21.0  OKC  NBA   PF   17.0   17.0  28.8  3.9   8.5  ...  0.825
# 2     2011-12  22.0  OKC  NBA   PF   20.0   20.0  28.5  4.2   8.0  ...  0.722
# 3     2012-13  23.0  OKC  NBA   PF   11.0   11.0  33.3  5.4  12.3  ...  0.792
# 4     2013-14  24.0  OKC  NBA   PF   17.0   17.0  34.2  5.1   8.6  ...  0.765
# 5     2015-16  26.0  OKC  NBA   PF   18.0   18.0  33.4  4.7   9.1  ...  0.750
# 6     2016-17  27.0  TOR  NBA   PF   10.0   10.0  30.7  6.0  13.0  ...  0.846
# 7     2017-18  28.0  TOR  NBA   PF   10.0    9.0  26.0  3.0   7.2  ...  0.818
# 8     2018-19  29.0  TOR  NBA    C   24.0    0.0  20.8  3.8   8.0  ...  0.762
# 9     2019-20  30.0  TOR  NBA    C   11.0    0.0  22.8  5.7  10.0  ...  1.000
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5   3.0  ...  1.000
# ...

# %%
df4[2]
# Out:
#                  Highlight  Unnamed: 1                        In Stathead
# 0      Career high, Points        34.0  View full stats from top 20 games
# 1    Career high, Rebounds        22.0  View full stats from top 20 games
# 2     Career high, Assists         6.0  View full stats from top 20 games
# 3      Career high, Steals         3.0  View full stats from top 20 games
# 4      Career high, Blocks        11.0  View full stats from top 20 games
# 5  Career high, Game Score        33.1  View full stats from top 20 games
# 6           Triple-Doubles         1.0                           View all

# %%
df4[3]
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS       MP      FG     FGA  \
# 0     2009-10  20.0  OKC  NBA   PF   73.0    0.0   1323.0   201.0   370.0
# 1     2010-11  21.0  OKC  NBA   PF   82.0   44.0   2216.0   335.0   617.0
# 2     2011-12  22.0  OKC  NBA   PF   66.0   66.0   1792.0   262.0   490.0
# 3     2012-13  23.0  OKC  NBA   PF   80.0   80.0   2486.0   446.0   778.0
# 4     2013-14  24.0  OKC  NBA   PF   81.0   81.0   2666.0   524.0   978.0
# 5     2014-15  25.0  OKC  NBA   PF   64.0   64.0   2116.0   374.0   786.0
# 6     2015-16  26.0  OKC  NBA   PF   78.0   78.0   2500.0   416.0   869.0
# 7     2016-17  27.0  TOT  NBA   PF   79.0   79.0   2422.0   471.0   982.0
# 8     2016-17  27.0  ORL  NBA   PF   56.0   56.0   1710.0   343.0   703.0
# 9     2016-17  27.0  TOR  NBA   PF   23.0   23.0    712.0   128.0   279.0
# 10    2017-18  28.0  TOR  NBA   PF   76.0   76.0   2093.0   379.0   784.0
# 11    2018-19  29.0  TOR  NBA    C   74.0   51.0   2010.0   464.0   877.0
# ...

# %%
df4[4]
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS      MP     FG     FGA  ...  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0    0.0   153.0   20.0    35.0  ...
# 1     2010-11  21.0  OKC  NBA   PF   17.0   17.0   490.0   67.0   145.0  ...
# 2     2011-12  22.0  OKC  NBA   PF   20.0   20.0   569.0   84.0   159.0  ...
# 3     2012-13  23.0  OKC  NBA   PF   11.0   11.0   366.0   59.0   135.0  ...
# 4     2013-14  24.0  OKC  NBA   PF   17.0   17.0   581.0   87.0   147.0  ...
# 5     2015-16  26.0  OKC  NBA   PF   18.0   18.0   602.0   85.0   163.0  ...
# 6     2016-17  27.0  TOR  NBA   PF   10.0   10.0   307.0   60.0   130.0  ...
# 7     2017-18  28.0  TOR  NBA   PF   10.0    9.0   260.0   30.0    72.0  ...
# 8     2018-19  29.0  TOR  NBA    C   24.0    0.0   500.0   92.0   193.0  ...
# 9     2019-20  30.0  TOR  NBA    C   11.0    0.0   251.0   63.0   110.0  ...
# 10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0     6.0  ...
# ...

# %%
df4[5]
# Out:
#        Season   Age   Tm   Lg  Pos      G       MP   PER    TS%   3PAr  ...  \
# 0     2009-10  20.0  OKC  NBA   PF   73.0   1323.0  15.2  0.562  0.005  ...
# 1     2010-11  21.0  OKC  NBA   PF   82.0   2216.0  17.7  0.579  0.002  ...
# 2     2011-12  22.0  OKC  NBA   PF   66.0   1792.0  19.0  0.556  0.006  ...
# 3     2012-13  23.0  OKC  NBA   PF   80.0   2486.0  19.4  0.612  0.073  ...
# 4     2013-14  24.0  OKC  NBA   PF   81.0   2666.0  19.6  0.576  0.061  ...
# 5     2014-15  25.0  OKC  NBA   PF   64.0   2116.0  16.6  0.549  0.261  ...
# 6     2015-16  26.0  OKC  NBA   PF   78.0   2500.0  13.9  0.533  0.212  ...
# 7     2016-17  27.0  TOT  NBA   PF   79.0   2422.0  16.4  0.566  0.323  ...
# 8     2016-17  27.0  ORL  NBA   PF   56.0   1710.0  17.5  0.569  0.304  ...
# 9     2016-17  27.0  TOR  NBA   PF   23.0    712.0  13.8  0.556  0.369  ...
# 10    2017-18  28.0  TOR  NBA   PF   76.0   2093.0  14.7  0.574  0.379  ...
# ...

# %%
df4[5]
# Out:
#        Season   Age   Tm   Lg  Pos      G       MP   PER    TS%   3PAr  ...  \
# 0     2009-10  20.0  OKC  NBA   PF   73.0   1323.0  15.2  0.562  0.005  ...
# 1     2010-11  21.0  OKC  NBA   PF   82.0   2216.0  17.7  0.579  0.002  ...
# 2     2011-12  22.0  OKC  NBA   PF   66.0   1792.0  19.0  0.556  0.006  ...
# 3     2012-13  23.0  OKC  NBA   PF   80.0   2486.0  19.4  0.612  0.073  ...
# 4     2013-14  24.0  OKC  NBA   PF   81.0   2666.0  19.6  0.576  0.061  ...
# 5     2014-15  25.0  OKC  NBA   PF   64.0   2116.0  16.6  0.549  0.261  ...
# 6     2015-16  26.0  OKC  NBA   PF   78.0   2500.0  13.9  0.533  0.212  ...
# 7     2016-17  27.0  TOT  NBA   PF   79.0   2422.0  16.4  0.566  0.323  ...
# 8     2016-17  27.0  ORL  NBA   PF   56.0   1710.0  17.5  0.569  0.304  ...
# 9     2016-17  27.0  TOR  NBA   PF   23.0    712.0  13.8  0.556  0.369  ...
# 10    2017-18  28.0  TOR  NBA   PF   76.0   2093.0  14.7  0.574  0.379  ...
# ...

# %%
df4[5]
# Out:
#        Season   Age   Tm   Lg  Pos      G       MP   PER    TS%   3PAr  ...  \
# 0     2009-10  20.0  OKC  NBA   PF   73.0   1323.0  15.2  0.562  0.005  ...
# 1     2010-11  21.0  OKC  NBA   PF   82.0   2216.0  17.7  0.579  0.002  ...
# 2     2011-12  22.0  OKC  NBA   PF   66.0   1792.0  19.0  0.556  0.006  ...
# 3     2012-13  23.0  OKC  NBA   PF   80.0   2486.0  19.4  0.612  0.073  ...
# 4     2013-14  24.0  OKC  NBA   PF   81.0   2666.0  19.6  0.576  0.061  ...
# 5     2014-15  25.0  OKC  NBA   PF   64.0   2116.0  16.6  0.549  0.261  ...
# 6     2015-16  26.0  OKC  NBA   PF   78.0   2500.0  13.9  0.533  0.212  ...
# 7     2016-17  27.0  TOT  NBA   PF   79.0   2422.0  16.4  0.566  0.323  ...
# 8     2016-17  27.0  ORL  NBA   PF   56.0   1710.0  17.5  0.569  0.304  ...
# 9     2016-17  27.0  TOR  NBA   PF   23.0    712.0  13.8  0.556  0.369  ...
# 10    2017-18  28.0  TOR  NBA   PF   76.0   2093.0  14.7  0.574  0.379  ...
# ...

# %%
df4[6]
# Out:
#        Season   Age   Tm   Lg  Pos      G      MP   PER    TS%   3PAr  ...  \
# 0     2009-10  20.0  OKC  NBA   PF    6.0   153.0  15.3  0.596  0.000  ...
# 1     2010-11  21.0  OKC  NBA   PF   17.0   490.0  15.2  0.514  0.007  ...
# 2     2011-12  22.0  OKC  NBA   PF   20.0   569.0  18.9  0.558  0.025  ...
# 3     2012-13  23.0  OKC  NBA   PF   11.0   366.0  17.1  0.484  0.067  ...
# 4     2013-14  24.0  OKC  NBA   PF   17.0   581.0  16.6  0.633  0.088  ...
# 5     2015-16  26.0  OKC  NBA   PF   18.0   602.0  15.3  0.629  0.423  ...
# 6     2016-17  27.0  TOR  NBA   PF   10.0   307.0  14.4  0.527  0.292  ...
# 7     2017-18  28.0  TOR  NBA   PF   10.0   260.0  10.9  0.533  0.333  ...
# 8     2018-19  29.0  TOR  NBA    C   24.0   500.0  15.0  0.532  0.197  ...
# 9     2019-20  30.0  TOR  NBA    C   11.0   251.0  25.2  0.702  0.409  ...
# 10    2020-21  31.0  LAC  NBA    C    2.0    18.0  30.7  0.644  0.333  ...
# ...

# %% [markdown]
# # Store this data Into CSV Format

# %%
df4[3].to_csv('Web_player3_data.csv')

# %% [markdown]
# # Create all Table in my dir

# %%
html_data = pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html')
for i in range(len(html_data)):
    html_data[i].to_csv(f'html_data{i}.csv',index = False)

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...
